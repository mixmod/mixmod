# %% [markdown]
# # Apprentissage

# %% [markdown]
# Importations :

# %%
import pandas as pd

import mixmod

# %% [markdown]
# Chargement des données :

# %%
data = pd.read_csv("../../data/iris.csv")
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# On va utiliser la colonne **species** pour construire le vecteur de libellés et on va soumettre les données sans cette colonne :

# %%
iris_learn = mixmod.learn(data.iloc[:, :4], data.iloc[:, 4])
# Out:
# CALL LEARN DEALLOC

# %% [markdown]
# Résultats :

# %%
print(iris_learn)
# Out:
# ****************************************
# *** INPUT:
# ****************************************
# * nbCluster = 3
# * criterion = CV
# ****************************************
# *** MIXMOD Models:
# * list = b'Gaussian_pk_Lk_C'
# ****************************************
# * data =
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# ...
